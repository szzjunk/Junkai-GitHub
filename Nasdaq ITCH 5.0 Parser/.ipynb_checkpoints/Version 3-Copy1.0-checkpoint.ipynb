# %%
#import gzip
#import shutil
from pathlib import Path
#from urllib.request import urlretrieve
from datetime import datetime
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter
from struct import unpack
from collections import namedtuple, Counter
from datetime import timedelta
from time import time

# %%
### Set Data paths

# %%
data_path = Path('D:/') # set to e.g. external harddrive
itch_store = str(data_path / 'itch.h5')
order_book_store = data_path / 'order_book.h5'

# %%
data_path
# Out:
# WindowsPath('D:/')

# %%
## ITCH Format Settings
### System Event Codes – Daily

# %%
event_codes = {'O': 'Start of Messages',
               'S': 'Start of System Hours',
               'Q': 'Start of Market Hours',
               'M': 'End of Market Hours',
               'E': 'End of System Hours',
               'C': 'End of Messages'}

# %%
encoding = {'primary_market_maker': {'Y': 1, 'N': 0},
            'printable'           : {'Y': 1, 'N': 0},
            'buy_sell_indicator'  : {'B': 1, 'S': -1},
            'cross_type'          : {'O': 0, 'C': 1, 'H': 2},         # “O” = Opening Cross, “C” = Closing Cross, 
                                                                      # “H” = Cross for IPO and halted / paused securities
            'imbalance_direction' : {'B': 0, 'S': 1, 'N': 0, 'O': -1}}
                                                                      # “B” = buy imbalance, “S” = sell imbalance
                                                                      # “N” = no imbalance, “O” = Insufficient orders to calculate

# %%
### Formats Dictionary 
#### It is used to assemble the format strings

# %%
formats = { ('integer', 2): 'H',   # int of length 2 => format string 'H'
            ('integer', 4): 'I',
            ('integer', 6): '6s',  # int of length 6 => parse as string, convert later
            ('integer', 8): 'Q',
            ('alpha', 1)  : 's',
            ('alpha', 2)  : '2s',
            ('alpha', 4)  : '4s',
            ('alpha', 8)  : '8s',
            ('price_4', 4): 'I',
            ('price_8', 8): 'Q', }

# %%
#### Basic Cleaning

# %%
def clean_message_types(df):
    # transfer all the columns' name into lower case and remove all the leading and trailing spaces
    df.columns = [c.lower().strip() for c in df.columns]
    # remove all the leading and trailing spaces in the values
    df.value = df.value.str.strip()
    # clean all values in the name column 
    df.name = (df.name
               .str.strip()
               .str.lower()
               .str.replace(' ', '_')
               .str.replace('-', '_')
               .str.replace('/', '_'))
    # clean all values in the notes column 
    df.notes = df.notes.str.strip()
    # add message type column
    df['message_type'] = df.loc[df.name == 'message_type', 'value']
    return df

# %%
#### Load Message Types

# %%
message_types = clean_message_types(pd.read_excel('message_types.xlsx', sheet_name='messages', encoding='latin1')
                                    .sort_values('id').drop('id', axis=1))

# %%
message_types
# Out:
#                                name  offset  length      value  \
# 0                      message_type       0       1          S
# 1                      stock_locate       1       2    Integer
# 2                   tracking_number       3       2    Integer
# 3                         timestamp       5       6    Integer
# 4                        event_code      11       1      Alpha
# 5                      message_type       0       1          R
# 6                      stock_locate       1       2    Integer
# 7                   tracking_number       3       2    Integer
# 8                         timestamp       5       6    Integer
# 9                             stock      11       8      Alpha
# 10                  market_category      19       1      Alpha
# 11       financial_status_indicator      20       1      Alpha
# 12                   round_lot_size      21       4    Integer
# 13                  round_lots_only      25       1      Alpha
# 14             issue_classification      26       1      Alpha
# 15                   issue_sub_type      27       2      Alpha
# 16                     authenticity      29       1      Alpha
# 17   short_sale_threshold_indicator      30       1      Alpha
# 18                         ipo_flag      31       1      Alpha
# 19        luld_reference_price_tier      32       1      Alpha
# 20                         etp_flag      33       1      Alpha
# 21              etp_leverage_factor      34       4    Integer
# 22                inverse_indicator      38       1      Alpha
# 23                     message_type       0       1          H
# 24                     stock_locate       1       2    Integer
# 25                  tracking_number       3       2    Integer
# 26                        timestamp       5       6    Integer
# 27                            stock      11       8      Alpha
# 28                    trading_state      19       1      Alpha
# 29                         reserved      20       1      Alpha
# ..                              ...     ...     ...        ...
# 143                           stock      24       8      Alpha
# 144                           price      32       4  Price (4)
# 145                    match_number      36       8    Integer
# 146                    message_type       0       1          Q
# 147                    stock_locate       1       2    Integer
# 148                 tracking_number       3       2    Integer
# 149                       timestamp       5       6    Integer
# 150                          shares      11       8    Integer
# 151                           stock      19       8      Alpha
# 152                     cross_price      27       4  Price (4)
# 153                    match_number      31       8    Integer
# 154                      cross_type      39       1      Alpha
# 155                    message_type       0       1          B
# 156                    stock_locate       1       2    Integer
# 157                 tracking_number       3       2    Integer
# 158                       timestamp       5       6    Integer
# 159                    match_number      11       8    Integer
# 160                    message_type       0       1          I
# 161                    stock_locate       1       2    Integer
# 162                 tracking_number       3       2    Integer
# 163                       timestamp       5       6    Integer
# 164                   paired_shares      11       8    Integer
# 165                imbalance_shares      19       8    Integer
# 166             imbalance_direction      27       1      Alpha
# 167                           stock      28       8      Alpha
# 168                       far_price      36       4  Price (4)
# 169                      near_price      40       4  Price (4)
# 170         current_reference_price      44       4  Price (4)
# 171                      cross_type      48       1      Alpha
# 172       price_variation_indicator      49       1      Alpha
#
#                                                  notes message_type
# 0                                 System Event Message            S
# 1                                             Always 0          NaN
# 2                      Nasdaq internal tracking number          NaN
# 3                           Nanoseconds since midnight          NaN
# 4                         See System Event Codes below          NaN
# 5                              Stock Directory Message            R
# 6    Locate Code uniquely assigned to the security ...          NaN
# 7                      Nasdaq internal tracking number          NaN
# 8    Time at which the directory message was genera...          NaN
# 9    Denotes the security symbol for the issue in t...          NaN
# 10   Indicates Listing market or listing market tie...          NaN
# 11   For Nasdaq listed issues, this field indicates...          NaN
# 12   Denotes the number of shares that represent a ...          NaN
# 13   Indicates if Nasdaq system limits order entry ...          NaN
# 14   Identifies the security class for the issue as...          NaN
# 15   Identifies the security sub-type for the issue...          NaN
# 16   Denotes if an issue or quoting participant rec...          NaN
# 17   Indicates if a security is subject to mandator...          NaN
# 18   Indicates if the Nasdaq security is set up for...          NaN
# 19   Indicates which Limit Up / Limit Down price ba...          NaN
# 20   Indicates whether the security is an exchange ...          NaN
# 21   Tracks the integral relationship of the ETP to...          NaN
# 22   Indicates the directional relationship between...          NaN
# 23                       Stock Trading Action Message.            H
# 24                Locate code identifying the security          NaN
# 25                     Nasdaq internal tracking number          NaN
# 26                          Nanoseconds since midnight          NaN
# 27              Stock symbol, right padded with spaces          NaN
# 28   Indicates the current trading state for the st...          NaN
# 29                                           Reserved.          NaN
# ..                                                 ...          ...
# 143             Stock Symbol, right padded with spaces          NaN
# 144  The match price of the order. Please refer to ...          NaN
# 145  The Nasdaq generated session unique Match Numb...          NaN
# 146                                Cross Trade Message            Q
# 147               Locate code identifying the security          NaN
# 148                    Nasdaq internal tracking number          NaN
# 149                        Nanoseconds since midnight.          NaN
# 150  The number of shares matched in the Nasdaq Cross.          NaN
# 151             Stock symbol, right padded with spaces          NaN
# 152  The price at which the cross occurred. Refer t...          NaN
# 153  The Nasdaq generated day-unique Match Number o...          NaN
# 154  The Nasdaq cross session for which the message...          NaN
# 155                              Broken Trade Message.            B
# 156               Locate code identifying the security          NaN
# 157                    Nasdaq internal tracking number          NaN
# 158                        Nanoseconds since midnight.          NaN
# 159  The Nasdaq Match Number of the execution that ...          NaN
# 160                                       NOII Message            I
# 161               Locate code identifying the security          NaN
# 162                    Nasdaq internal tracking number          NaN
# 163                        Nanoseconds since midnight.          NaN
# 164  The total number of shares that are eligible t...          NaN
# 165  The number of shares not paired at the Current...          NaN
# 166  The market side of the order imbalance. \nB = ...          NaN
# 167             Stock symbol, right padded with spaces          NaN
# 168  A hypothetical auction-clearing price for cros...          NaN
# 169  A hypothetical auction-clearing price for cros...          NaN
# 170  The price at which the NOII shares are being c...          NaN
# 171  The type of Nasdaq cross for which the NOII me...          NaN
# 172  This field indicates the absolute value of the...          NaN
#
# [173 rows x 6 columns]

# %%
#### Get Message Labels

# %%
# extract the notes and message type columns that has value
message_labels = (message_types.loc[:, ['message_type', 'notes']]
                  .dropna()
                  .rename(columns={'notes': 'name'}))
# clean the notes column
message_labels.name = (message_labels.name
                       .str.lower()
                       .str.replace('message', '')
                       .str.replace('.', '')
                       .str.strip().str.replace(' ', '_'))
# message_labels.to_csv('message_labels.csv', index=False)

# %%
message_types
# Out:
#                                name  offset  length      value  \
# 0                      message_type       0       1          S
# 1                      stock_locate       1       2    Integer
# 2                   tracking_number       3       2    Integer
# 3                         timestamp       5       6    Integer
# 4                        event_code      11       1      Alpha
# 5                      message_type       0       1          R
# 6                      stock_locate       1       2    Integer
# 7                   tracking_number       3       2    Integer
# 8                         timestamp       5       6    Integer
# 9                             stock      11       8      Alpha
# 10                  market_category      19       1      Alpha
# 11       financial_status_indicator      20       1      Alpha
# 12                   round_lot_size      21       4    Integer
# 13                  round_lots_only      25       1      Alpha
# 14             issue_classification      26       1      Alpha
# 15                   issue_sub_type      27       2      Alpha
# 16                     authenticity      29       1      Alpha
# 17   short_sale_threshold_indicator      30       1      Alpha
# 18                         ipo_flag      31       1      Alpha
# 19        luld_reference_price_tier      32       1      Alpha
# 20                         etp_flag      33       1      Alpha
# 21              etp_leverage_factor      34       4    Integer
# 22                inverse_indicator      38       1      Alpha
# 23                     message_type       0       1          H
# 24                     stock_locate       1       2    Integer
# 25                  tracking_number       3       2    Integer
# 26                        timestamp       5       6    Integer
# 27                            stock      11       8      Alpha
# 28                    trading_state      19       1      Alpha
# 29                         reserved      20       1      Alpha
# ..                              ...     ...     ...        ...
# 143                           stock      24       8      Alpha
# 144                           price      32       4  Price (4)
# 145                    match_number      36       8    Integer
# 146                    message_type       0       1          Q
# 147                    stock_locate       1       2    Integer
# 148                 tracking_number       3       2    Integer
# 149                       timestamp       5       6    Integer
# 150                          shares      11       8    Integer
# 151                           stock      19       8      Alpha
# 152                     cross_price      27       4  Price (4)
# 153                    match_number      31       8    Integer
# 154                      cross_type      39       1      Alpha
# 155                    message_type       0       1          B
# 156                    stock_locate       1       2    Integer
# 157                 tracking_number       3       2    Integer
# 158                       timestamp       5       6    Integer
# 159                    match_number      11       8    Integer
# 160                    message_type       0       1          I
# 161                    stock_locate       1       2    Integer
# 162                 tracking_number       3       2    Integer
# 163                       timestamp       5       6    Integer
# 164                   paired_shares      11       8    Integer
# 165                imbalance_shares      19       8    Integer
# 166             imbalance_direction      27       1      Alpha
# 167                           stock      28       8      Alpha
# 168                       far_price      36       4  Price (4)
# 169                      near_price      40       4  Price (4)
# 170         current_reference_price      44       4  Price (4)
# 171                      cross_type      48       1      Alpha
# 172       price_variation_indicator      49       1      Alpha
#
#                                                  notes message_type
# 0                                 System Event Message            S
# 1                                             Always 0          NaN
# 2                      Nasdaq internal tracking number          NaN
# 3                           Nanoseconds since midnight          NaN
# 4                         See System Event Codes below          NaN
# 5                              Stock Directory Message            R
# 6    Locate Code uniquely assigned to the security ...          NaN
# 7                      Nasdaq internal tracking number          NaN
# 8    Time at which the directory message was genera...          NaN
# 9    Denotes the security symbol for the issue in t...          NaN
# 10   Indicates Listing market or listing market tie...          NaN
# 11   For Nasdaq listed issues, this field indicates...          NaN
# 12   Denotes the number of shares that represent a ...          NaN
# 13   Indicates if Nasdaq system limits order entry ...          NaN
# 14   Identifies the security class for the issue as...          NaN
# 15   Identifies the security sub-type for the issue...          NaN
# 16   Denotes if an issue or quoting participant rec...          NaN
# 17   Indicates if a security is subject to mandator...          NaN
# 18   Indicates if the Nasdaq security is set up for...          NaN
# 19   Indicates which Limit Up / Limit Down price ba...          NaN
# 20   Indicates whether the security is an exchange ...          NaN
# 21   Tracks the integral relationship of the ETP to...          NaN
# 22   Indicates the directional relationship between...          NaN
# 23                       Stock Trading Action Message.            H
# 24                Locate code identifying the security          NaN
# 25                     Nasdaq internal tracking number          NaN
# 26                          Nanoseconds since midnight          NaN
# 27              Stock symbol, right padded with spaces          NaN
# 28   Indicates the current trading state for the st...          NaN
# 29                                           Reserved.          NaN
# ..                                                 ...          ...
# 143             Stock Symbol, right padded with spaces          NaN
# 144  The match price of the order. Please refer to ...          NaN
# 145  The Nasdaq generated session unique Match Numb...          NaN
# 146                                Cross Trade Message            Q
# 147               Locate code identifying the security          NaN
# 148                    Nasdaq internal tracking number          NaN
# 149                        Nanoseconds since midnight.          NaN
# 150  The number of shares matched in the Nasdaq Cross.          NaN
# 151             Stock symbol, right padded with spaces          NaN
# 152  The price at which the cross occurred. Refer t...          NaN
# 153  The Nasdaq generated day-unique Match Number o...          NaN
# 154  The Nasdaq cross session for which the message...          NaN
# 155                              Broken Trade Message.            B
# 156               Locate code identifying the security          NaN
# 157                    Nasdaq internal tracking number          NaN
# 158                        Nanoseconds since midnight.          NaN
# 159  The Nasdaq Match Number of the execution that ...          NaN
# 160                                       NOII Message            I
# 161               Locate code identifying the security          NaN
# 162                    Nasdaq internal tracking number          NaN
# 163                        Nanoseconds since midnight.          NaN
# 164  The total number of shares that are eligible t...          NaN
# 165  The number of shares not paired at the Current...          NaN
# 166  The market side of the order imbalance. \nB = ...          NaN
# 167             Stock symbol, right padded with spaces          NaN
# 168  A hypothetical auction-clearing price for cros...          NaN
# 169  A hypothetical auction-clearing price for cros...          NaN
# 170  The price at which the NOII shares are being c...          NaN
# 171  The type of Nasdaq cross for which the NOII me...          NaN
# 172  This field indicates the absolute value of the...          NaN
#
# [173 rows x 6 columns]

# %%
# fill NA in the message_type column
message_types.message_type = message_types.message_type.ffill()
# remove the message type in the rows
message_types = message_types[message_types.name != 'message_type']
# clean the value column in the data frame
message_types.value = (message_types.value
                       .str.lower()
                       .str.replace(' ', '_')
                       .str.replace('(', '')
                       .str.replace(')', ''))
message_types.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 152 entries, 1 to 172
# Data columns (total 6 columns):
# name            152 non-null object
# offset          152 non-null int64
# length          152 non-null int64
# value           152 non-null object
# notes           152 non-null object
# message_type    152 non-null object
# dtypes: int64(2), object(4)
# memory usage: 8.3+ KB
# C:\Users\KevinZhang\Anaconda3\lib\site-packages\pandas\core\generic.py:4401: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   self[name] = value

# %%
message_types
# Out:
#                                name  offset  length    value  \
# 1                      stock_locate       1       2  integer
# 2                   tracking_number       3       2  integer
# 3                         timestamp       5       6  integer
# 4                        event_code      11       1    alpha
# 6                      stock_locate       1       2  integer
# 7                   tracking_number       3       2  integer
# 8                         timestamp       5       6  integer
# 9                             stock      11       8    alpha
# 10                  market_category      19       1    alpha
# 11       financial_status_indicator      20       1    alpha
# 12                   round_lot_size      21       4  integer
# 13                  round_lots_only      25       1    alpha
# 14             issue_classification      26       1    alpha
# 15                   issue_sub_type      27       2    alpha
# 16                     authenticity      29       1    alpha
# 17   short_sale_threshold_indicator      30       1    alpha
# 18                         ipo_flag      31       1    alpha
# 19        luld_reference_price_tier      32       1    alpha
# 20                         etp_flag      33       1    alpha
# 21              etp_leverage_factor      34       4  integer
# 22                inverse_indicator      38       1    alpha
# 24                     stock_locate       1       2  integer
# 25                  tracking_number       3       2  integer
# 26                        timestamp       5       6  integer
# 27                            stock      11       8    alpha
# 28                    trading_state      19       1    alpha
# 29                         reserved      20       1    alpha
# 30                           reason      21       4    alpha
# 32                     stock_locate       1       2  integer
# 33                  tracking_number       3       2  integer
# ..                              ...     ...     ...      ...
# 140          order_reference_number      11       8  integer
# 141              buy_sell_indicator      19       1    alpha
# 142                          shares      20       4  integer
# 143                           stock      24       8    alpha
# 144                           price      32       4  price_4
# 145                    match_number      36       8  integer
# 147                    stock_locate       1       2  integer
# 148                 tracking_number       3       2  integer
# 149                       timestamp       5       6  integer
# 150                          shares      11       8  integer
# 151                           stock      19       8    alpha
# 152                     cross_price      27       4  price_4
# 153                    match_number      31       8  integer
# 154                      cross_type      39       1    alpha
# 156                    stock_locate       1       2  integer
# 157                 tracking_number       3       2  integer
# 158                       timestamp       5       6  integer
# 159                    match_number      11       8  integer
# 161                    stock_locate       1       2  integer
# 162                 tracking_number       3       2  integer
# 163                       timestamp       5       6  integer
# 164                   paired_shares      11       8  integer
# 165                imbalance_shares      19       8  integer
# 166             imbalance_direction      27       1    alpha
# 167                           stock      28       8    alpha
# 168                       far_price      36       4  price_4
# 169                      near_price      40       4  price_4
# 170         current_reference_price      44       4  price_4
# 171                      cross_type      48       1    alpha
# 172       price_variation_indicator      49       1    alpha
#
#                                                  notes message_type
# 1                                             Always 0            S
# 2                      Nasdaq internal tracking number            S
# 3                           Nanoseconds since midnight            S
# 4                         See System Event Codes below            S
# 6    Locate Code uniquely assigned to the security ...            R
# 7                      Nasdaq internal tracking number            R
# 8    Time at which the directory message was genera...            R
# 9    Denotes the security symbol for the issue in t...            R
# 10   Indicates Listing market or listing market tie...            R
# 11   For Nasdaq listed issues, this field indicates...            R
# 12   Denotes the number of shares that represent a ...            R
# 13   Indicates if Nasdaq system limits order entry ...            R
# 14   Identifies the security class for the issue as...            R
# 15   Identifies the security sub-type for the issue...            R
# 16   Denotes if an issue or quoting participant rec...            R
# 17   Indicates if a security is subject to mandator...            R
# 18   Indicates if the Nasdaq security is set up for...            R
# 19   Indicates which Limit Up / Limit Down price ba...            R
# 20   Indicates whether the security is an exchange ...            R
# 21   Tracks the integral relationship of the ETP to...            R
# 22   Indicates the directional relationship between...            R
# 24                Locate code identifying the security            H
# 25                     Nasdaq internal tracking number            H
# 26                          Nanoseconds since midnight            H
# 27              Stock symbol, right padded with spaces            H
# 28   Indicates the current trading state for the st...            H
# 29                                           Reserved.            H
# 30                              Trading Action reason.            H
# 32                Locate code identifying the security            Y
# 33                     Nasdaq internal tracking number            Y
# ..                                                 ...          ...
# 140  The unique reference number assigned to the or...            P
# 141  The type of non-display order on the book bein...            P
# 142  The number of shares being matched in this exe...            P
# 143             Stock Symbol, right padded with spaces            P
# 144  The match price of the order. Please refer to ...            P
# 145  The Nasdaq generated session unique Match Numb...            P
# 147               Locate code identifying the security            Q
# 148                    Nasdaq internal tracking number            Q
# 149                        Nanoseconds since midnight.            Q
# 150  The number of shares matched in the Nasdaq Cross.            Q
# 151             Stock symbol, right padded with spaces            Q
# 152  The price at which the cross occurred. Refer t...            Q
# 153  The Nasdaq generated day-unique Match Number o...            Q
# 154  The Nasdaq cross session for which the message...            Q
# 156               Locate code identifying the security            B
# 157                    Nasdaq internal tracking number            B
# 158                        Nanoseconds since midnight.            B
# 159  The Nasdaq Match Number of the execution that ...            B
# 161               Locate code identifying the security            I
# 162                    Nasdaq internal tracking number            I
# 163                        Nanoseconds since midnight.            I
# 164  The total number of shares that are eligible t...            I
# 165  The number of shares not paired at the Current...            I
# 166  The market side of the order imbalance. \nB = ...            I
# 167             Stock symbol, right padded with spaces            I
# 168  A hypothetical auction-clearing price for cros...            I
# 169  A hypothetical auction-clearing price for cros...            I
# 170  The price at which the NOII shares are being c...            I
# 171  The type of Nasdaq cross for which the NOII me...            I
# 172  This field indicates the absolute value of the...            I
#
# [152 rows x 6 columns]

# %%
### Get message specification

# %%
# Get ITCH specs and create formatting (type, length) tuples
specs = message_types
specs['formats'] = specs[['value', 'length']].apply(tuple, axis=1).map(formats)
# Out:
# C:\Users\KevinZhang\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
specs
# Out:
#                                name  offset  length    value  \
# 1                      stock_locate       1       2  integer
# 2                   tracking_number       3       2  integer
# 3                         timestamp       5       6  integer
# 4                        event_code      11       1    alpha
# 6                      stock_locate       1       2  integer
# 7                   tracking_number       3       2  integer
# 8                         timestamp       5       6  integer
# 9                             stock      11       8    alpha
# 10                  market_category      19       1    alpha
# 11       financial_status_indicator      20       1    alpha
# 12                   round_lot_size      21       4  integer
# 13                  round_lots_only      25       1    alpha
# 14             issue_classification      26       1    alpha
# 15                   issue_sub_type      27       2    alpha
# 16                     authenticity      29       1    alpha
# 17   short_sale_threshold_indicator      30       1    alpha
# 18                         ipo_flag      31       1    alpha
# 19        luld_reference_price_tier      32       1    alpha
# 20                         etp_flag      33       1    alpha
# 21              etp_leverage_factor      34       4  integer
# 22                inverse_indicator      38       1    alpha
# 24                     stock_locate       1       2  integer
# 25                  tracking_number       3       2  integer
# 26                        timestamp       5       6  integer
# 27                            stock      11       8    alpha
# 28                    trading_state      19       1    alpha
# 29                         reserved      20       1    alpha
# 30                           reason      21       4    alpha
# 32                     stock_locate       1       2  integer
# 33                  tracking_number       3       2  integer
# ..                              ...     ...     ...      ...
# 140          order_reference_number      11       8  integer
# 141              buy_sell_indicator      19       1    alpha
# 142                          shares      20       4  integer
# 143                           stock      24       8    alpha
# 144                           price      32       4  price_4
# 145                    match_number      36       8  integer
# 147                    stock_locate       1       2  integer
# 148                 tracking_number       3       2  integer
# 149                       timestamp       5       6  integer
# 150                          shares      11       8  integer
# 151                           stock      19       8    alpha
# 152                     cross_price      27       4  price_4
# 153                    match_number      31       8  integer
# 154                      cross_type      39       1    alpha
# 156                    stock_locate       1       2  integer
# 157                 tracking_number       3       2  integer
# 158                       timestamp       5       6  integer
# 159                    match_number      11       8  integer
# 161                    stock_locate       1       2  integer
# 162                 tracking_number       3       2  integer
# 163                       timestamp       5       6  integer
# 164                   paired_shares      11       8  integer
# 165                imbalance_shares      19       8  integer
# 166             imbalance_direction      27       1    alpha
# 167                           stock      28       8    alpha
# 168                       far_price      36       4  price_4
# 169                      near_price      40       4  price_4
# 170         current_reference_price      44       4  price_4
# 171                      cross_type      48       1    alpha
# 172       price_variation_indicator      49       1    alpha
#
#                                                  notes message_type formats
# 1                                             Always 0            S       H
# 2                      Nasdaq internal tracking number            S       H
# 3                           Nanoseconds since midnight            S      6s
# 4                         See System Event Codes below            S       s
# 6    Locate Code uniquely assigned to the security ...            R       H
# 7                      Nasdaq internal tracking number            R       H
# 8    Time at which the directory message was genera...            R      6s
# 9    Denotes the security symbol for the issue in t...            R      8s
# 10   Indicates Listing market or listing market tie...            R       s
# 11   For Nasdaq listed issues, this field indicates...            R       s
# 12   Denotes the number of shares that represent a ...            R       I
# 13   Indicates if Nasdaq system limits order entry ...            R       s
# 14   Identifies the security class for the issue as...            R       s
# 15   Identifies the security sub-type for the issue...            R      2s
# 16   Denotes if an issue or quoting participant rec...            R       s
# 17   Indicates if a security is subject to mandator...            R       s
# 18   Indicates if the Nasdaq security is set up for...            R       s
# 19   Indicates which Limit Up / Limit Down price ba...            R       s
# 20   Indicates whether the security is an exchange ...            R       s
# 21   Tracks the integral relationship of the ETP to...            R       I
# 22   Indicates the directional relationship between...            R       s
# 24                Locate code identifying the security            H       H
# 25                     Nasdaq internal tracking number            H       H
# 26                          Nanoseconds since midnight            H      6s
# 27              Stock symbol, right padded with spaces            H      8s
# 28   Indicates the current trading state for the st...            H       s
# 29                                           Reserved.            H       s
# 30                              Trading Action reason.            H      4s
# 32                Locate code identifying the security            Y       H
# 33                     Nasdaq internal tracking number            Y       H
# ..                                                 ...          ...     ...
# 140  The unique reference number assigned to the or...            P       Q
# 141  The type of non-display order on the book bein...            P       s
# 142  The number of shares being matched in this exe...            P       I
# 143             Stock Symbol, right padded with spaces            P      8s
# 144  The match price of the order. Please refer to ...            P       I
# 145  The Nasdaq generated session unique Match Numb...            P       Q
# 147               Locate code identifying the security            Q       H
# 148                    Nasdaq internal tracking number            Q       H
# 149                        Nanoseconds since midnight.            Q      6s
# 150  The number of shares matched in the Nasdaq Cross.            Q       Q
# 151             Stock symbol, right padded with spaces            Q      8s
# 152  The price at which the cross occurred. Refer t...            Q       I
# 153  The Nasdaq generated day-unique Match Number o...            Q       Q
# 154  The Nasdaq cross session for which the message...            Q       s
# 156               Locate code identifying the security            B       H
# 157                    Nasdaq internal tracking number            B       H
# 158                        Nanoseconds since midnight.            B      6s
# 159  The Nasdaq Match Number of the execution that ...            B       Q
# 161               Locate code identifying the security            I       H
# 162                    Nasdaq internal tracking number            I       H
# 163                        Nanoseconds since midnight.            I      6s
# 164  The total number of shares that are eligible t...            I       Q
# 165  The number of shares not paired at the Current...            I       Q
# 166  The market side of the order imbalance. \nB = ...            I       s
# 167             Stock symbol, right padded with spaces            I      8s
# 168  A hypothetical auction-clearing price for cros...            I       I
# 169  A hypothetical auction-clearing price for cros...            I       I
# 170  The price at which the NOII shares are being c...            I       I
# 171  The type of Nasdaq cross for which the NOII me...            I       s
# 172  This field indicates the absolute value of the...            I       s
#
# [152 rows x 7 columns]

# %%
# Extract formatting for alpha numerical fields
alpha_fields = specs[specs.value == 'alpha'].set_index('name')
alpha_msgs = alpha_fields.groupby('message_type')
alpha_formats = {k: v.to_dict() for k, v in alpha_msgs.formats}
alpha_length = {k: v.add(7).to_dict() for k, v in alpha_msgs.length}

# %%
alpha_fields
# Out:
#                                  offset  length  value  \
# name
# event_code                           11       1  alpha
# stock                                11       8  alpha
# market_category                      19       1  alpha
# financial_status_indicator           20       1  alpha
# round_lots_only                      25       1  alpha
# issue_classification                 26       1  alpha
# issue_sub_type                       27       2  alpha
# authenticity                         29       1  alpha
# short_sale_threshold_indicator       30       1  alpha
# ipo_flag                             31       1  alpha
# luld_reference_price_tier            32       1  alpha
# etp_flag                             33       1  alpha
# inverse_indicator                    38       1  alpha
# stock                                11       8  alpha
# trading_state                        19       1  alpha
# reserved                             20       1  alpha
# reason                               21       4  alpha
# stock                                11       8  alpha
# reg_sho_action                       19       1  alpha
# mpid                                 11       4  alpha
# stock                                15       8  alpha
# primary_market_maker                 23       1  alpha
# market_maker_mode                    24       1  alpha
# market_participant_state             25       1  alpha
# breached_level                       11       1  alpha
# stock                                11       8  alpha
# ipo_quotation_release_qualifier      23       1  alpha
# stock                                11       8  alpha
# stock                                11       8  alpha
# market_code                          19       1  alpha
# operational_halt_action              20       1  alpha
# buy_sell_indicator                   19       1  alpha
# stock                                24       8  alpha
# buy_sell_indicator                   19       1  alpha
# stock                                24       8  alpha
# attribution                          36       4  alpha
# printable                            31       1  alpha
# buy_sell_indicator                   19       1  alpha
# stock                                24       8  alpha
# stock                                19       8  alpha
# cross_type                           39       1  alpha
# imbalance_direction                  27       1  alpha
# stock                                28       8  alpha
# cross_type                           48       1  alpha
# price_variation_indicator            49       1  alpha
#
#                                                                              notes  \
# name
# event_code                                            See System Event Codes below
# stock                            Denotes the security symbol for the issue in t...
# market_category                  Indicates Listing market or listing market tie...
# financial_status_indicator       For Nasdaq listed issues, this field indicates...
# round_lots_only                  Indicates if Nasdaq system limits order entry ...
# issue_classification             Identifies the security class for the issue as...
# issue_sub_type                   Identifies the security sub-type for the issue...
# authenticity                     Denotes if an issue or quoting participant rec...
# short_sale_threshold_indicator   Indicates if a security is subject to mandator...
# ipo_flag                         Indicates if the Nasdaq security is set up for...
# luld_reference_price_tier        Indicates which Limit Up / Limit Down price ba...
# etp_flag                         Indicates whether the security is an exchange ...
# inverse_indicator                Indicates the directional relationship between...
# stock                                       Stock symbol, right padded with spaces
# trading_state                    Indicates the current trading state for the st...
# reserved                                                                 Reserved.
# reason                                                      Trading Action reason.
# stock                                       Stock symbol, right padded with spaces
# reg_sho_action                   Denotes the Reg SHO Short Sale Price Test Rest...
# mpid                             Denotes the market participant identifier for ...
# stock                                       Stock symbol, right padded with spaces
# primary_market_maker             Indicates if the market participant firm quali...
# market_maker_mode                Indicates the quoting participant's registrati...
# market_participant_state         Indicates the market participant's current reg...
# breached_level                   Denotes the MWCB Level that was breached. 1 = ...
# stock                                       Stock symbol, right padded with spaces
# ipo_quotation_release_qualifier  A = Anticipated Quotation Release Time: \nThis...
# stock                                       Stock symbol, right padded with spaces
# stock                            Denotes the security symbol for the issue in N...
# market_code                                                Q: Nasdaq\nB: BX\nX: PS
# operational_halt_action          H: Operationally Halted on the identified Mark...
# buy_sell_indicator               The type of order being added. B = Buy Order. ...
# stock                                       Stock symbol, right padded with spaces
# buy_sell_indicator               The type of order being added. B = Buy Order. ...
# stock                                       Stock symbol, right padded with spaces
# attribution                      Nasdaq Market participant identifier associate...
# printable                        Indicates if the execution should be reflected...
# buy_sell_indicator               The type of non-display order on the book bein...
# stock                                       Stock Symbol, right padded with spaces
# stock                                       Stock symbol, right padded with spaces
# cross_type                       The Nasdaq cross session for which the message...
# imbalance_direction              The market side of the order imbalance. \nB = ...
# stock                                       Stock symbol, right padded with spaces
# cross_type                       The type of Nasdaq cross for which the NOII me...
# price_variation_indicator        This field indicates the absolute value of the...
#
#                                 message_type formats
# name
# event_code                                 S       s
# stock                                      R      8s
# market_category                            R       s
# financial_status_indicator                 R       s
# round_lots_only                            R       s
# issue_classification                       R       s
# issue_sub_type                             R      2s
# authenticity                               R       s
# short_sale_threshold_indicator             R       s
# ipo_flag                                   R       s
# luld_reference_price_tier                  R       s
# etp_flag                                   R       s
# inverse_indicator                          R       s
# stock                                      H      8s
# trading_state                              H       s
# reserved                                   H       s
# reason                                     H      4s
# stock                                      Y      8s
# reg_sho_action                             Y       s
# mpid                                       L      4s
# stock                                      L      8s
# primary_market_maker                       L       s
# market_maker_mode                          L       s
# market_participant_state                   L       s
# breached_level                             W       s
# stock                                      K      8s
# ipo_quotation_release_qualifier            K       s
# stock                                      J      8s
# stock                                      h      8s
# market_code                                h       s
# operational_halt_action                    h       s
# buy_sell_indicator                         A       s
# stock                                      A      8s
# buy_sell_indicator                         F       s
# stock                                      F      8s
# attribution                                F      4s
# printable                                  C       s
# buy_sell_indicator                         P       s
# stock                                      P      8s
# stock                                      Q      8s
# cross_type                                 Q       s
# imbalance_direction                        I       s
# stock                                      I      8s
# cross_type                                 I       s
# price_variation_indicator                  I       s

# %%
alpha_msgs

# %%
alpha_formats
# Out:
# {'A': {'buy_sell_indicator': 's', 'stock': '8s'},
#  'C': {'printable': 's'},
#  'F': {'buy_sell_indicator': 's', 'stock': '8s', 'attribution': '4s'},
#  'H': {'stock': '8s', 'trading_state': 's', 'reserved': 's', 'reason': '4s'},
#  'I': {'imbalance_direction': 's',
#   'stock': '8s',
#   'cross_type': 's',
#   'price_variation_indicator': 's'},
#  'J': {'stock': '8s'},
#  'K': {'stock': '8s', 'ipo_quotation_release_qualifier': 's'},
#  'L': {'mpid': '4s',
#   'stock': '8s',
#   'primary_market_maker': 's',
#   'market_maker_mode': 's',
#   'market_participant_state': 's'},
#  'P': {'buy_sell_indicator': 's', 'stock': '8s'},
#  'Q': {'stock': '8s', 'cross_type': 's'},
#  'R': {'stock': '8s',
#   'market_category': 's',
#   'financial_status_indicator': 's',
#   'round_lots_only': 's',
#   'issue_classification': 's',
#   'issue_sub_type': '2s',
#   'authenticity': 's',
#   'short_sale_threshold_indicator': 's',
#   'ipo_flag': 's',
#   'luld_reference_price_tier': 's',
#   'etp_flag': 's',
#   'inverse_indicator': 's'},
#  'S': {'event_code': 's'},
#  'W': {'breached_level': 's'},
#  'Y': {'stock': '8s', 'reg_sho_action': 's'},
#  'h': {'stock': '8s', 'market_code': 's', 'operational_halt_action': 's'}}

# %%
alpha_length
# Out:
# {'A': {'buy_sell_indicator': 8, 'stock': 15},
#  'C': {'printable': 8},
#  'F': {'buy_sell_indicator': 8, 'stock': 15, 'attribution': 11},
#  'H': {'stock': 15, 'trading_state': 8, 'reserved': 8, 'reason': 11},
#  'I': {'imbalance_direction': 8,
#   'stock': 15,
#   'cross_type': 8,
#   'price_variation_indicator': 8},
#  'J': {'stock': 15},
#  'K': {'stock': 15, 'ipo_quotation_release_qualifier': 8},
#  'L': {'mpid': 11,
#   'stock': 15,
#   'primary_market_maker': 8,
#   'market_maker_mode': 8,
#   'market_participant_state': 8},
#  'P': {'buy_sell_indicator': 8, 'stock': 15},
#  'Q': {'stock': 15, 'cross_type': 8},
#  'R': {'stock': 15,
#   'market_category': 8,
#   'financial_status_indicator': 8,
#   'round_lots_only': 8,
#   'issue_classification': 8,
#   'issue_sub_type': 9,
#   'authenticity': 8,
#   'short_sale_threshold_indicator': 8,
#   'ipo_flag': 8,
#   'luld_reference_price_tier': 8,
#   'etp_flag': 8,
#   'inverse_indicator': 8},
#  'S': {'event_code': 8},
#  'W': {'breached_level': 8},
#  'Y': {'stock': 15, 'reg_sho_action': 8},
#  'h': {'stock': 15, 'market_code': 8, 'operational_halt_action': 8}}

# %%
# Generate message classes as named tuples and format strings
message_fields, fstring = {}, {}
for t, message in specs.groupby('message_type'):
    message_fields[t] = namedtuple(typename=t, field_names=message.name.tolist())
    fstring[t] = '>' + ''.join(message.formats.tolist())

# %%
fstring

# %%
def format_alpha(mtype, data):
    """Process byte strings of type alpha"""

    for col in alpha_formats.get(mtype).keys():
        if mtype != 'R' and col == 'stock':
            data = data.drop(col, axis=1)
            continue
        data.loc[:, col] = data.loc[:, col].str.decode("utf-8").str.strip()
        if encoding.get(col):
            data.loc[:, col] = data.loc[:, col].map(encoding.get(col))
    return data

# %%
## Process Messages

# %%
def store_messages(m):
    """Handle occasional storing of all messages"""
    with pd.HDFStore(itch_store) as store:
        for mtype, data in m.items():
            # convert to DataFrame
            data = pd.DataFrame(data)

            # parse timestamp info
            data.timestamp = data.timestamp.apply(int.from_bytes, byteorder='big')
            data.timestamp = pd.to_timedelta(data.timestamp)

            # apply alpha formatting
            if mtype in alpha_formats.keys():
                data = format_alpha(mtype, data)

            s = alpha_length.get(mtype)
            if s:
                s = {c: s.get(c) for c in data.columns}
            dc = ['stock_locate']
            if m == 'R':
                dc.append('stock')
            store.append(mtype,
                         data,
                         format='t',
                         min_itemsize=s,
                         data_columns=dc)

# %%
messages = {}
message_count = 0
message_type_counter = Counter()

# %%
start = time()
data  = open('D:/01302019.NASDAQ_ITCH50', mode='rb')
while True:

    # determine message size in bytes
    message_size = int.from_bytes(data.read(2), byteorder='big', signed=False)

    # get message type by reading first byte
    message_type = data.read(1).decode('ascii')

    # create data structure to capture result
    if not messages.get(message_type):
        messages[message_type] = []

    message_type_counter.update([message_type])

    # read & store message
    record = data.read(message_size - 1)
    message = message_fields[message_type]._make(unpack(fstring[message_type], record))
    messages[message_type].append(message)

    # deal with system events
    if message_type == 'S':
        timestamp = int.from_bytes(message.timestamp, byteorder='big')
        print('\n', event_codes.get(message.event_code.decode('ascii'), 'Error'))
        print('\t{0}\t{1:,.0f}'.format(timedelta(seconds=timestamp * 1e-9),
                                     message_count))
        if message.event_code.decode('ascii') == 'C':
            store_messages(messages)
            break

    message_count += 1
    if message_count % 2.5e7 == 0:
        timestamp = int.from_bytes(message.timestamp, byteorder='big')
        print('\t{0}\t{1:,.0f}\t{2}'.format(timedelta(seconds=timestamp * 1e-9),
                                            message_count,
                                            timedelta(seconds=time() - start)))
        store_messages(messages)
        messages = {}


print(timedelta(seconds=time() - start))
